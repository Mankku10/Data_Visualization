# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([2,5,6,10])

# %%
plt.plot([0,1,2,4],[2,5,6,10])

# %%
x = np.arange(-100 , 100)

# %%
sq = x**2

# %%
plt.plot(x,sq)

# %%
cube = x**3

# %%
plt.plot(x,cube)

# %%
plt.plot(x,sq)
plt.plot(x,cube)

# %%
plt.plot(x,sq)
plt.plot(x,cube)

plt.ylim(-10000 , 10000)
# Out:
# (-10000, 10000)

# %%
plt.figure()

plt.plot(x,sq , label="squre")
plt.plot(x,cube, label="cube")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.ylim(-10000 , 10000)
# Out:
# (-10000, 10000)

# %%
x = np.linspace(-np.pi,np.pi,100)

# %%
sin = np.sin(x)
cos = np.cos(x)

# %%
plt.plot(sin)
plt.plot(cos)

# %%
a=5
x_c , y_c =100,100

# %%
plt.plot(a*np.sin(x)+x_c,a*np.cos(x)+y_c)

# %%
x = np.linspace(-np.pi,np.pi*10,500)
a = np.linspace(0 , 70 ,500)
plt.plot(a*np.sin(x)+x_c,a*np.cos(x)+y_c)

# %%
img = np.zeros([100,100])

# %%
center=(50,50)

# %%
for row in range(img.shape[0]):
    for col in range(img.shape[1]):
        
        distance = np.sqrt((row-center[0])**2 + (col-center[1])**2)
        img[row ,col] = distance %10

# %%
plt.imshow(img , cmap="gray")
